# %% [markdown]
# ### Define some helper functions

# %%
from collections import defaultdict
import numpy as np
import torch

def evaluate_model(model, loader, eval_functions, mode="eval"):
    """Evaluate model on a data loader with given evaluation functions.
    Assumes metrics can be computed in batches and averaged."""
    orig_mode = model.training
    model.train(mode == "train")

    metrics = defaultdict(list)

    with torch.no_grad():
        for x, y in loader:
            preds = model(x)

            for name, fn in eval_functions.items():
                metrics[name].append(fn(preds, y).to(torch.float32).mean().item())

    model.train(orig_mode)

    return {name: np.mean(vals) for name, vals in metrics.items()}


def load_n(loader, n):
    i = 0
    while i < n:
        for x in loader:
            yield x
            i += 1
            if i == n:
                break

# %% [markdown]
# ### Create MNIST dataloaders
# We add a transform that turns each pixels into a single bit (0.-> False everyhting else -> True). This is standard procedure on MNIST. For other datasets, we would typically represent each pixel as multiple bits (binarization).

# %%
# turn inputs into binary values
from torchvision import datasets, transforms
from torchvision.transforms import v2
from torch.utils.data import DataLoader

batch_size = 128

transform = v2.Compose([
    transforms.ToTensor(),
    transforms.Lambda(lambda x: (x > 0.).float())
])
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ### Build the model and loss function
# We use a very simple convolutional model. This won't perform well, but it demonstrates a variety of `torchlogix`'s layers. Standard cross entropy for training and accurcay for training. Adam works well as optimizer, but notice the larger-than-usal learning rate!

# %%
from torchlogix.layers import LogicDense, LogicConv2d, GroupSum, OrPooling2d

model = torch.nn.Sequential(
    LogicConv2d(in_dim=28, channels=1, num_kernels=16, tree_depth=2, receptive_field_size=3),  # 
    OrPooling2d(kernel_size=2, stride=2, padding=0),  # Reduce dimensionality with pooling operation
    torch.nn.Flatten(),
    LogicDense(16*13*13, 4_000),
    LogicDense(4_000, 4_000),
    GroupSum(k=10, tau=8)  # classify into ten classes
)

loss_fn = torch.nn.CrossEntropyLoss()
eval_functions = {
    "loss": loss_fn,
    "acc": lambda preds, y: (preds.argmax(-1) == y).to(torch.float32).mean(),
}
optimizer = torch.optim.Adam(model.parameters(), lr=0.02)

# %% [markdown]
# ### Run the training loop
# Standard training loop, but we evaluate the model in relaxed (`train`) and discrete (`eval`) mode.

# %%
num_iterations = 1000
eval_freq = 100
running_train_loss, n = 0.0, 0
metrics_dict = {"step": [], "test_acc_discrete": [], "test_loss_discrete": [], "test_acc_relaxed": [], "test_loss_relaxed": [], "train_loss": []}
for i, (x, y) in enumerate(load_n(train_loader, num_iterations)):
    model.train()
    x = model(x)
    loss = loss_fn(x, y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    bsz = y.size(0)
    n += bsz
    running_train_loss += loss.detach() * bsz
    # Evaluation
    if (eval_freq > 0 and ((i + 1) % eval_freq == 0)):
        # Evaluate on validation set
        discrete_metrics = evaluate_model(
            model, test_loader, eval_functions, mode="eval"
        )
        relaxed_metrics = evaluate_model(
            model, test_loader, eval_functions, mode="train"
        )

        metrics = \
            {f"test_{k}_discrete": v for k, v in discrete_metrics.items()} | \
            {f"test_{k}_relaxed": v for k, v in relaxed_metrics.items()} | \
            {"train_loss": running_train_loss.cpu().item() / n}

        for k, v in metrics.items():
            metrics_dict[k].append(v)
        metrics_dict["step"].append(i + 1)

        print(f"Iteration {i + 1:6d} | " +
                " | ".join([f"{k}: {v:.4f}" for k, v in metrics.items()]))

        running_train_loss, n = 0.0, 0
# Out:
# Iteration    100 | test_loss_discrete: 2.8078 | test_acc_discrete: 0.0833 | test_loss_relaxed: 0.7503 | test_acc_relaxed: 0.8121 | train_loss: 1.4577
# Iteration    200 | test_loss_discrete: 1.0710 | test_acc_discrete: 0.6646 | test_loss_relaxed: 0.4616 | test_acc_relaxed: 0.8746 | train_loss: 0.5818
# Iteration    300 | test_loss_discrete: 0.5560 | test_acc_discrete: 0.8322 | test_loss_relaxed: 0.3797 | test_acc_relaxed: 0.8951 | train_loss: 0.4339
# Iteration    400 | test_loss_discrete: 0.4385 | test_acc_discrete: 0.8654 | test_loss_relaxed: 0.3350 | test_acc_relaxed: 0.9042 | train_loss: 0.3808
# Iteration    500 | test_loss_discrete: 0.3862 | test_acc_discrete: 0.8811 | test_loss_relaxed: 0.3145 | test_acc_relaxed: 0.9097 | train_loss: 0.3286
# Iteration    600 | test_loss_discrete: 0.3483 | test_acc_discrete: 0.8895 | test_loss_relaxed: 0.2968 | test_acc_relaxed: 0.9092 | train_loss: 0.3075
# Iteration    700 | test_loss_discrete: 0.3418 | test_acc_discrete: 0.8909 | test_loss_relaxed: 0.2799 | test_acc_relaxed: 0.9154 | train_loss: 0.3020
# Iteration    800 | test_loss_discrete: 0.3179 | test_acc_discrete: 0.9010 | test_loss_relaxed: 0.2722 | test_acc_relaxed: 0.9182 | train_loss: 0.2913
# Iteration    900 | test_loss_discrete: 0.3011 | test_acc_discrete: 0.9061 | test_loss_relaxed: 0.2600 | test_acc_relaxed: 0.9215 | train_loss: 0.2753
# Iteration   1000 | test_loss_discrete: 0.2863 | test_acc_discrete: 0.9092 | test_loss_relaxed: 0.2524 | test_acc_relaxed: 0.9264 | train_loss: 0.2620

# %% [markdown]
# ### Plot the results
# Note that the two curves are both on the test set. The difference is relaxed vs discrete model.

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2, 1)
axs[0].plot(metrics_dict["step"], metrics_dict["test_acc_discrete"], "--", c="b", label="Discrete")
axs[0].plot(metrics_dict["step"], metrics_dict["test_acc_relaxed"], "--", c="r", label="Relaxed")
axs[0].set_ylabel("Test Accuracy")
axs[0].grid()
axs[0].legend()
axs[1].plot(metrics_dict["step"], metrics_dict["test_loss_relaxed"], "--", c="b", label="Relaxed")
axs[1].plot(metrics_dict["step"], metrics_dict["test_loss_discrete"], "--", c="r", label="Discrete")
axs[1].legend()
axs[1].set_ylabel("Test Loss")
axs[1].grid()
fig.supxlabel("Training Step")
# Out:
# Text(0.5, 0.01, 'Training Step')

# %% [markdown]
# ### Build the boolean circuit
# We first set the model into `export_mode`. This replaces the standard forward pass with purely boolean expressions. We can then trace it and turn it into `torchlogix`'s custom IR (`Circuit`), which is a fully unrolled computational graph whose nodes are individual logic ops or sum reductions. We simplify the graph with constant propagation, dead code elimination, etc., which significantly reduces the number of nodes.

# %%
from torchlogix import Circuit
from torchlogix.utils import set_export_mode

set_export_mode(model)
circuit = Circuit.from_model(model, input_shape=(1, 28, 28))
print(f"Original circuit: {circuit}")
circuit.simplify()
print(f"Simplified circuit: {circuit}")
# Out:
# /Users/linogerlach/Projects/ML/alkaid/venv/lib/python3.13/site-packages/torch/fx/experimental/const_fold.py:353: UserWarning: Attempted to insert a get_attr Node with no underlying reference in the owning GraphModule! Call GraphModule.add_submodule to add the necessary submodule, GraphModule.add_parameter to add the necessary Parameter, or nn.Module.register_buffer to add the necessary buffer
#   new_node = root_const_gm.graph.get_attr(in_node.target)
# Original circuit: Circuit(
#   n_inputs=784,
#   input_shape=[1, 28, 28],
#   logic_nodes=16497,
#   sum_nodes=10,
#   output_shape=[10]
# )
# Simplified circuit: Circuit(
#   n_inputs=784,
#   input_shape=[1, 28, 28],
#   logic_nodes=6673,
#   sum_nodes=10,
#   output_shape=[10]
# )

# %% [markdown]
# ### Profile inference speed
# First, we build a large test set that contains several batches. Then, we compile the circuit. This writes .C to a tmp file, compiles it, and loads the shared object with python bindings. Lastly, we assert that the outputs match.

# %%
from datetime import datetime

all_X = []
for x, y in load_n(test_loader, 64):  # Load 100 batches for profiling
    all_X.append(x)
all_X = torch.cat(all_X, dim=0).bool()
all_X_np = all_X.numpy()
print(f"all_X shape: {all_X.shape}")

t0 = datetime.now()
all_preds = model(all_X)
print("Time for original model:", datetime.now() - t0)

circuit.compile()
t0 = datetime.now()
all_preds_compiled = circuit(all_X_np, use_compiled=True)
print("Time for compiled model:", datetime.now() - t0)

assert torch.allclose(all_preds, torch.from_numpy(all_preds_compiled).float(), atol=1e-4), "Predictions do not match!"
# Out:
# all_X shape: torch.Size([8192, 1, 28, 28])
# Time for original model: 0:00:01.260145
# Time for compiled model: 0:00:00.026414

# %% [markdown]
# ### Advanced compilation options
# Inference can be sped-up even further w/ bit packing and higher compiler optimizations. On my macbook, the inference takes less than 5ms, wich amounts to a throughput of roughly 1.6M images per second.

# %%
circuit.compile(pack_bits=32, opt_level=4)

t0 = datetime.now()
all_preds_compiled = circuit(all_X_np, use_compiled=True)
print("Time for compiled model without thresholding:", datetime.now() - t0)

assert torch.allclose(all_preds, torch.from_numpy(all_preds_compiled), atol=1e-4), "Predictions do not match!"
# Out:
# Time for compiled model without thresholding: 0:00:00.003819

# %% [markdown]
# ### Generating HDL code
# An instance of `Circuit` can also emit `verilog` code:

# %%
s = circuit.get_verilog_code(inline_single_use=False)
print(s)
# Out:
# // Auto-generated by circuit_ir - do not edit
# // Input shape:  [1, 28, 28]
# // Output shape: [10]
# // n_inputs=784  n_gates=6673  n_outputs=10
#
# // 10 output(s) - scores_flat = 10 x 32-bit values
# module circuit (
#     input  wire [783:0] inp,
#     output reg  [319:0] scores_flat
# );
#     wire g1460 = (inp[0] & inp[28]);
#     wire g1461 = (inp[1] & inp[29]);
#     wire g1464 = (inp[4] & inp[32]);
#     wire g1465 = (inp[5] & inp[33]);
#     wire g1466 = (inp[6] & inp[34]);
#     wire g1467 = (inp[7] & inp[35]);
#     wire g1468 = (inp[8] & inp[36]);
#     wire g1469 = (inp[9] & inp[37]);
#     wire g1470 = (inp[10] & inp[38]);
#     wire g1471 = (inp[11] & inp[39]);
#     wire g1472 = (inp[12] & inp[40]);
#     wire g1473 = (inp[13] & inp[41]);
#     wire g1474 = (inp[14] & inp[42]);
#     wire g1475 = (inp[15] & inp[43]);
#     wire g1476 = (inp[16] & inp[44]);
#     wire g1477 = (inp[17] & inp[45]);
#     wire g1478 = (inp[18] & inp[46]);
#     wire g1479 = (inp[19] & inp[47]);
#     wire g1480 = (inp[20] & inp[48]);
#     wire g1481 = (inp[21] & inp[49]);
#     wire g1482 = (inp[22] & inp[50]);
#     wire g1483 = (inp[23] & inp[51]);
#     wire g1484 = (inp[24] & inp[52]);
#     wire g1485 = (inp[25] & inp[53]);
#     wire g1486 = (inp[28] & inp[56]);
#     wire g1487 = (inp[29] & inp[57]);
#     wire g1490 = (inp[32] & inp[60]);
#     wire g1491 = (inp[33] & inp[61]);
#     wire g1492 = (inp[34] & inp[62]);
#     wire g1493 = (inp[35] & inp[63]);
#     wire g1494 = (inp[36] & inp[64]);
#     wire g1495 = (inp[37] & inp[65]);
#     wire g1496 = (inp[38] & inp[66]);
#     wire g1497 = (inp[39] & inp[67]);
#     wire g1498 = (inp[40] & inp[68]);
#     wire g1499 = (inp[41] & inp[69]);
#     wire g1500 = (inp[42] & inp[70]);
#     wire g1501 = (inp[43] & inp[71]);
#     wire g1502 = (inp[44] & inp[72]);
#     wire g1503 = (inp[45] & inp[73]);
#     wire g1504 = (inp[46] & inp[74]);
#     wire g1505 = (inp[47] & inp[75]);
#     wire g1506 = (inp[48] & inp[76]);
#     wire g1507 = (inp[49] & inp[77]);
#     wire g1508 = (inp[50] & inp[78]);
#     wire g1509 = (inp[51] & inp[79]);
#     wire g1510 = (inp[52] & inp[80]);
#     wire g1511 = (inp[53] & inp[81]);
#     wire g1512 = (inp[56] & inp[84]);
#     wire g1513 = (inp[57] & inp[85]);
#     wire g1514 = (inp[58] & inp[86]);
#     wire g1515 = (inp[59] & inp[87]);
#     wire g1518 = (inp[62] & inp[90]);
#     wire g1519 = (inp[63] & inp[91]);
#     wire g1520 = (inp[64] & inp[92]);
#     wire g1521 = (inp[65] & inp[93]);
#     wire g1522 = (inp[66] & inp[94]);
#     wire g1523 = (inp[67] & inp[95]);
#     wire g1524 = (inp[68] & inp[96]);
#     wire g1525 = (inp[69] & inp[97]);
#     wire g1526 = (inp[70] & inp[98]);
#     wire g1527 = (inp[71] & inp[99]);
#     wire g1528 = (inp[72] & inp[100]);
#     wire g1529 = (inp[73] & inp[101]);
#     wire g1530 = (inp[74] & inp[102]);
#     wire g1531 = (inp[75] & inp[103]);
#     wire g1532 = (inp[76] & inp[104]);
#     wire g1533 = (inp[77] & inp[105]);
#     wire g1534 = (inp[78] & inp[106]);
#     wire g1535 = (inp[79] & inp[107]);
#     wire g1536 = (inp[80] & inp[108]);
#     wire g1537 = (inp[81] & inp[109]);
#     wire g1538 = (inp[84] & inp[112]);
#     wire g1539 = (inp[85] & inp[113]);
#     wire g1540 = (inp[86] & inp[114]);
#     wire g1541 = (inp[87] & inp[115]);
#     wire g1544 = (inp[90] & inp[118]);
#     wire g1545 = (inp[91] & inp[119]);
#     wire g1546 = (inp[92] & inp[120]);
#     wire g1547 = (inp[93] & inp[121]);
#     wire g1548 = (inp[94] & inp[122]);
#     wire g1549 = (inp[95] & inp[123]);
#     wire g1550 = (inp[96] & inp[124]);
#     wire g1551 = (inp[97] & inp[125]);
#     wire g1552 = (inp[98] & inp[126]);
#     wire g1553 = (inp[99] & inp[127]);
#     wire g1554 = (inp[100] & inp[128]);
#     wire g1555 = (inp[101] & inp[129]);
#     wire g1556 = (inp[102] & inp[130]);
#     wire g1557 = (inp[103] & inp[131]);
#     wire g1558 = (inp[104] & inp[132]);
#     wire g1559 = (inp[105] & inp[133]);
#     wire g1560 = (inp[106] & inp[134]);
#     wire g1561 = (inp[107] & inp[135]);
#     wire g1562 = (inp[108] & inp[136]);
#     wire g1563 = (inp[109] & inp[137]);
#     wire g1564 = (inp[112] & inp[140]);
#     wire g1565 = (inp[113] & inp[141]);
#     wire g1566 = (inp[114] & inp[142]);
#     wire g1567 = (inp[115] & inp[143]);
#     wire g1568 = (inp[116] & inp[144]);
#     wire g1569 = (inp[117] & inp[145]);
#     wire g1570 = (inp[118] & inp[146]);
#     wire g1571 = (inp[119] & inp[147]);
#     wire g1572 = (inp[120] & inp[148]);
#     wire g1573 = (inp[121] & inp[149]);
#     wire g1574 = (inp[122] & inp[150]);
#     wire g1575 = (inp[123] & inp[151]);
#     wire g1576 = (inp[124] & inp[152]);
#     wire g1577 = (inp[125] & inp[153]);
#     wire g1578 = (inp[126] & inp[154]);
#     wire g1579 = (inp[127] & inp[155]);
#     wire g1580 = (inp[128] & inp[156]);
#     wire g1581 = (inp[129] & inp[157]);
#     wire g1582 = (inp[130] & inp[158]);
#     wire g1583 = (inp[131] & inp[159]);
#     wire g1584 = (inp[132] & inp[160]);
#     wire g1585 = (inp[133] & inp[161]);
#     wire g1586 = (inp[134] & inp[162]);
#     wire g1587 = (inp[135] & inp[163]);
#     wire g1588 = (inp[136] & inp[164]);
#     wire g1589 = (inp[137] & inp[165]);
#     wire g1590 = (inp[140] & inp[168]);
#     wire g1591 = (inp[141] & inp[169]);
#     wire g1592 = (inp[142] & inp[170]);
#     wire g1593 = (inp[143] & inp[171]);
#     wire g1594 = (inp[144] & inp[172]);
#     wire g1595 = (inp[145] & inp[173]);
#     wire g1596 = (inp[146] & inp[174]);
#     wire g1597 = (inp[147] & inp[175]);
#     wire g1598 = (inp[148] & inp[176]);
#     wire g1599 = (inp[149] & inp[177]);
#     wire g1600 = (inp[150] & inp[178]);
#     wire g1601 = (inp[151] & inp[179]);
#     wire g1602 = (inp[152] & inp[180]);
#     wire g1603 = (inp[153] & inp[181]);
#     wire g1604 = (inp[154] & inp[182]);
#     wire g1605 = (inp[155] & inp[183]);
#     wire g1606 = (inp[156] & inp[184]);
#     wire g1607 = (inp[157] & inp[185]);
#     wire g1608 = (inp[158] & inp[186]);
#     wire g1609 = (inp[159] & inp[187]);
#     wire g1610 = (inp[160] & inp[188]);
#     wire g1611 = (inp[161] & inp[189]);
#     wire g1612 = (inp[162] & inp[190]);
#     wire g1613 = (inp[163] & inp[191]);
#     wire g1614 = (inp[164] & inp[192]);
#     wire g1615 = (inp[165] & inp[193]);
#     wire g1618 = (inp[170] & inp[198]);
#     wire g1619 = (inp[171] & inp[199]);
#     wire g1620 = (inp[172] & inp[200]);
#     wire g1621 = (inp[173] & inp[201]);
#     wire g1622 = (inp[174] & inp[202]);
#     wire g1623 = (inp[175] & inp[203]);
#     wire g1624 = (inp[176] & inp[204]);
#     wire g1625 = (inp[177] & inp[205]);
#     wire g1626 = (inp[178] & inp[206]);
#     wire g1627 = (inp[179] & inp[207]);
#     wire g1628 = (inp[180] & inp[208]);
#     wire g1629 = (inp[181] & inp[209]);
#     wire g1630 = (inp[182] & inp[210]);
#     wire g1631 = (inp[183] & inp[211]);
#     wire g1632 = (inp[184] & inp[212]);
#     wire g1633 = (inp[185] & inp[213]);
#     wire g1634 = (inp[186] & inp[214]);
#     wire g1635 = (inp[187] & inp[215]);
#     wire g1636 = (inp[188] & inp[216]);
#     wire g1637 = (inp[189] & inp[217]);
#     wire g1638 = (inp[190] & inp[218]);
#     wire g1639 = (inp[191] & inp[219]);
#     wire g1640 = (inp[192] & inp[220]);
#     wire g1641 = (inp[193] & inp[221]);
#     wire g1644 = (inp[198] & inp[226]);
#     wire g1645 = (inp[199] & inp[227]);
#     wire g1646 = (inp[200] & inp[228]);
#     wire g1647 = (inp[201] & inp[229]);
#     wire g1648 = (inp[202] & inp[230]);
#     wire g1649 = (inp[203] & inp[231]);
#     wire g1650 = (inp[204] & inp[232]);
#     wire g1651 = (inp[205] & inp[233]);
#     wire g1652 = (inp[206] & inp[234]);
#     wire g1653 = (inp[207] & inp[235]);
#     wire g1654 = (inp[208] & inp[236]);
#     wire g1655 = (inp[209] & inp[237]);
#     wire g1656 = (inp[210] & inp[238]);
#     wire g1657 = (inp[211] & inp[239]);
#     wire g1658 = (inp[212] & inp[240]);
#     wire g1659 = (inp[213] & inp[241]);
#     wire g1660 = (inp[214] & inp[242]);
#     wire g1661 = (inp[215] & inp[243]);
#     wire g1662 = (inp[216] & inp[244]);
#     wire g1663 = (inp[217] & inp[245]);
#     wire g1664 = (inp[218] & inp[246]);
#     wire g1665 = (inp[219] & inp[247]);
#     wire g1666 = (inp[220] & inp[248]);
#     wire g1667 = (inp[221] & inp[249]);
#     wire g1668 = (inp[224] & inp[252]);
#     wire g1669 = (inp[225] & inp[253]);
#     wire g1670 = (inp[226] & inp[254]);
#     wire g1671 = (inp[227] & inp[255]);
#     wire g1672 = (inp[228] & inp[256]);
#     wire g1673 = (inp[229] & inp[257]);
#     wire g1674 = (inp[230] & inp[258]);
#     wire g1675 = (inp[231] & inp[259]);
#     wire g1678 = (inp[234] & inp[262]);
#     wire g1679 = (inp[235] & inp[263]);
#     wire g1680 = (inp[236] & inp[264]);
#     wire g1681 = (inp[237] & inp[265]);
#     wire g1682 = (inp[238] & inp[266]);
#     wire g1683 = (inp[239] & inp[267]);
#     wire g1684 = (inp[240] & inp[268]);
#     wire g1685 = (inp[241] & inp[269]);
#     wire g1686 = (inp[242] & inp[270]);
#     wire g1687 = (inp[243] & inp[271]);
#     wire g1688 = (inp[244] & inp[272]);
#     wire g1689 = (inp[245] & inp[273]);
#     wire g1690 = (inp[246] & inp[274]);
#     wire g1691 = (inp[247] & inp[275]);
#     wire g1692 = (inp[248] & inp[276]);
#     wire g1693 = (inp[249] & inp[277]);
#     wire g1694 = (inp[252] & inp[280]);
#     wire g1695 = (inp[253] & inp[281]);
#     wire g1696 = (inp[254] & inp[282]);
#     wire g1697 = (inp[255] & inp[283]);
#     wire g1698 = (inp[256] & inp[284]);
#     wire g1699 = (inp[257] & inp[285]);
#     wire g1700 = (inp[258] & inp[286]);
#     wire g1701 = (inp[259] & inp[287]);
#     wire g1704 = (inp[262] & inp[290]);
#     wire g1705 = (inp[263] & inp[291]);
#     wire g1706 = (inp[264] & inp[292]);
#     wire g1707 = (inp[265] & inp[293]);
#     wire g1708 = (inp[266] & inp[294]);
#     wire g1709 = (inp[267] & inp[295]);
#     wire g1710 = (inp[268] & inp[296]);
#     wire g1711 = (inp[269] & inp[297]);
#     wire g1712 = (inp[270] & inp[298]);
#     wire g1713 = (inp[271] & inp[299]);
#     wire g1714 = (inp[272] & inp[300]);
#     wire g1715 = (inp[273] & inp[301]);
#     wire g1716 = (inp[274] & inp[302]);
#     wire g1717 = (inp[275] & inp[303]);
#     wire g1718 = (inp[276] & inp[304]);
#     wire g1719 = (inp[277] & inp[305]);
#     wire g1720 = (inp[280] & inp[308]);
#     wire g1721 = (inp[281] & inp[309]);
#     wire g1722 = (inp[282] & inp[310]);
#     wire g1723 = (inp[283] & inp[311]);
#     wire g1724 = (inp[284] & inp[312]);
#     wire g1725 = (inp[285] & inp[313]);
#     wire g1726 = (inp[286] & inp[314]);
#     wire g1727 = (inp[287] & inp[315]);
#     wire g1728 = (inp[288] & inp[316]);
#     wire g1729 = (inp[289] & inp[317]);
#     wire g1730 = (inp[290] & inp[318]);
#     wire g1731 = (inp[291] & inp[319]);
#     wire g1732 = (inp[292] & inp[320]);
#     wire g1733 = (inp[293] & inp[321]);
#     wire g1734 = (inp[294] & inp[322]);
#     wire g1735 = (inp[295] & inp[323]);
#     wire g1736 = (inp[296] & inp[324]);
#     wire g1737 = (inp[297] & inp[325]);
#     wire g1738 = (inp[298] & inp[326]);
#     wire g1739 = (inp[299] & inp[327]);
#     wire g1740 = (inp[300] & inp[328]);
#     wire g1741 = (inp[301] & inp[329]);
#     wire g1742 = (inp[302] & inp[330]);
#     wire g1743 = (inp[303] & inp[331]);
#     wire g1744 = (inp[304] & inp[332]);
#     wire g1745 = (inp[305] & inp[333]);
#     wire g1746 = (inp[308] & inp[336]);
#     wire g1747 = (inp[309] & inp[337]);
#     wire g1748 = (inp[310] & inp[338]);
#     wire g1749 = (inp[311] & inp[339]);
#     wire g1750 = (inp[312] & inp[340]);
#     wire g1751 = (inp[313] & inp[341]);
#     wire g1752 = (inp[314] & inp[342]);
#     wire g1753 = (inp[315] & inp[343]);
#     wire g1754 = (inp[316] & inp[344]);
#     wire g1755 = (inp[317] & inp[345]);
#     wire g1756 = (inp[318] & inp[346]);
#     wire g1757 = (inp[319] & inp[347]);
#     wire g1758 = (inp[320] & inp[348]);
#     wire g1759 = (inp[321] & inp[349]);
#     wire g1760 = (inp[322] & inp[350]);
#     wire g1761 = (inp[323] & inp[351]);
#     wire g1762 = (inp[324] & inp[352]);
#     wire g1763 = (inp[325] & inp[353]);
#     wire g1764 = (inp[326] & inp[354]);
#     wire g1765 = (inp[327] & inp[355]);
#     wire g1766 = (inp[328] & inp[356]);
#     wire g1767 = (inp[329] & inp[357]);
#     wire g1768 = (inp[330] & inp[358]);
#     wire g1769 = (inp[331] & inp[359]);
#     wire g1770 = (inp[332] & inp[360]);
#     wire g1771 = (inp[333] & inp[361]);
#     wire g1772 = (inp[336] & inp[364]);
#     wire g1773 = (inp[337] & inp[365]);
#     wire g1774 = (inp[338] & inp[366]);
#     wire g1775 = (inp[339] & inp[367]);
#     wire g1776 = (inp[340] & inp[368]);
#     wire g1777 = (inp[341] & inp[369]);
#     wire g1778 = (inp[342] & inp[370]);
#     wire g1779 = (inp[343] & inp[371]);
#     wire g1780 = (inp[344] & inp[372]);
#     wire g1781 = (inp[345] & inp[373]);
#     wire g1782 = (inp[346] & inp[374]);
#     wire g1783 = (inp[347] & inp[375]);
#     wire g1784 = (inp[348] & inp[376]);
#     wire g1785 = (inp[349] & inp[377]);
#     wire g1786 = (inp[350] & inp[378]);
#     wire g1787 = (inp[351] & inp[379]);
#     wire g1788 = (inp[352] & inp[380]);
#     wire g1789 = (inp[353] & inp[381]);
#     wire g1790 = (inp[354] & inp[382]);
#     wire g1791 = (inp[355] & inp[383]);
#     wire g1792 = (inp[356] & inp[384]);
#     wire g1793 = (inp[357] & inp[385]);
#     wire g1794 = (inp[358] & inp[386]);
#     wire g1795 = (inp[359] & inp[387]);
#     wire g1796 = (inp[360] & inp[388]);
#     wire g1797 = (inp[361] & inp[389]);
#     wire g1798 = (inp[364] & inp[392]);
#     wire g1799 = (inp[365] & inp[393]);
#     wire g1800 = (inp[366] & inp[394]);
#     wire g1801 = (inp[367] & inp[395]);
#     wire g1802 = (inp[368] & inp[396]);
#     wire g1803 = (inp[369] & inp[397]);
#     wire g1804 = (inp[370] & inp[398]);
#     wire g1805 = (inp[371] & inp[399]);
#     wire g1806 = (inp[372] & inp[400]);
#     wire g1807 = (inp[373] & inp[401]);
#     wire g1808 = (inp[374] & inp[402]);
#     wire g1809 = (inp[375] & inp[403]);
#     wire g1810 = (inp[376] & inp[404]);
#     wire g1811 = (inp[377] & inp[405]);
#     wire g1812 = (inp[378] & inp[406]);
#     wire g1813 = (inp[379] & inp[407]);
#     wire g1814 = (inp[380] & inp[408]);
#     wire g1815 = (inp[381] & inp[409]);
#     wire g1816 = (inp[382] & inp[410]);
#     wire g1817 = (inp[383] & inp[411]);
#     wire g1818 = (inp[384] & inp[412]);
#     wire g1819 = (inp[385] & inp[413]);
#     wire g1820 = (inp[386] & inp[414]);
#     wire g1821 = (inp[387] & inp[415]);
#     wire g1822 = (inp[388] & inp[416]);
#     wire g1823 = (inp[389] & inp[417]);
#     wire g1824 = (inp[392] & inp[420]);
#     wire g1825 = (inp[393] & inp[421]);
#     wire g1826 = (inp[394] & inp[422]);
#     wire g1827 = (inp[395] & inp[423]);
#     wire g1828 = (inp[396] & inp[424]);
#     wire g1829 = (inp[397] & inp[425]);
#     wire g1830 = (inp[398] & inp[426]);
#     wire g1831 = (inp[399] & inp[427]);
#     wire g1832 = (inp[400] & inp[428]);
#     wire g1833 = (inp[401] & inp[429]);
#     wire g1834 = (inp[402] & inp[430]);
#     wire g1835 = (inp[403] & inp[431]);
#     wire g1836 = (inp[404] & inp[432]);
#     wire g1837 = (inp[405] & inp[433]);
#     wire g1838 = (inp[406] & inp[434]);
#     wire g1839 = (inp[407] & inp[435]);
#     wire g1840 = (inp[408] & inp[436]);
#     wire g1841 = (inp[409] & inp[437]);
#     wire g1842 = (inp[410] & inp[438]);
#     wire g1843 = (inp[411] & inp[439]);
#     wire g1844 = (inp[412] & inp[440]);
#     wire g1845 = (inp[413] & inp[441]);
#     wire g1846 = (inp[414] & inp[442]);
#     wire g1847 = (inp[415] & inp[443]);
#     wire g1848 = (inp[416] & inp[444]);
#     wire g1849 = (inp[417] & inp[445]);
#     wire g1850 = (inp[420] & inp[448]);
#     wire g1851 = (inp[421] & inp[449]);
#     wire g1852 = (inp[422] & inp[450]);
#     wire g1853 = (inp[423] & inp[451]);
#     wire g1854 = (inp[424] & inp[452]);
#     wire g1855 = (inp[425] & inp[453]);
#     wire g1856 = (inp[426] & inp[454]);
#     wire g1857 = (inp[427] & inp[455]);
#     wire g1858 = (inp[428] & inp[456]);
#     wire g1859 = (inp[429] & inp[457]);
#     wire g1860 = (inp[430] & inp[458]);
#     wire g1861 = (inp[431] & inp[459]);
#     wire g1862 = (inp[432] & inp[460]);
#     wire g1863 = (inp[433] & inp[461]);
#     wire g1864 = (inp[434] & inp[462]);
#     wire g1865 = (inp[435] & inp[463]);
#     wire g1866 = (inp[436] & inp[464]);
#     wire g1867 = (inp[437] & inp[465]);
#     wire g1868 = (inp[438] & inp[466]);
#     wire g1869 = (inp[439] & inp[467]);
#     wire g1870 = (inp[440] & inp[468]);
#     wire g1871 = (inp[441] & inp[469]);
#     wire g1872 = (inp[442] & inp[470]);
#     wire g1873 = (inp[443] & inp[471]);
#     wire g1874 = (inp[444] & inp[472]);
#     wire g1875 = (inp[445] & inp[473]);
#     wire g1876 = (inp[448] & inp[476]);
#     wire g1877 = (inp[449] & inp[477]);
#     wire g1878 = (inp[450] & inp[478]);
#     wire g1879 = (inp[451] & inp[479]);
#     wire g1880 = (inp[452] & inp[480]);
#     wire g1881 = (inp[453] & inp[481]);
#     wire g1882 = (inp[454] & inp[482]);
#     wire g1883 = (inp[455] & inp[483]);
#     wire g1884 = (inp[456] & inp[484]);
#     wire g1885 = (inp[457] & inp[485]);
#     wire g1886 = (inp[458] & inp[486]);
#     wire g1887 = (inp[459] & inp[487]);
#     wire g1888 = (inp[460] & inp[488]);
#     wire g1889 = (inp[461] & inp[489]);
#     wire g1890 = (inp[462] & inp[490]);
#     wire g1891 = (inp[463] & inp[491]);
#     wire g1892 = (inp[464] & inp[492]);
#     wire g1893 = (inp[465] & inp[493]);
#     wire g1894 = (inp[466] & inp[494]);
#     wire g1895 = (inp[467] & inp[495]);
#     wire g1896 = (inp[468] & inp[496]);
#     wire g1897 = (inp[469] & inp[497]);
#     wire g1898 = (inp[470] & inp[498]);
#     wire g1899 = (inp[471] & inp[499]);
#     wire g1900 = (inp[472] & inp[500]);
#     wire g1901 = (inp[473] & inp[501]);
#     wire g1902 = (inp[476] & inp[504]);
#     wire g1903 = (inp[477] & inp[505]);
#     wire g1904 = (inp[478] & inp[506]);
#     wire g1905 = (inp[479] & inp[507]);
#     wire g1906 = (inp[480] & inp[508]);
#     wire g1907 = (inp[481] & inp[509]);
#     wire g1908 = (inp[482] & inp[510]);
#     wire g1909 = (inp[483] & inp[511]);
#     wire g1910 = (inp[484] & inp[512]);
#     wire g1911 = (inp[485] & inp[513]);
#     wire g1912 = (inp[486] & inp[514]);
#     wire g1913 = (inp[487] & inp[515]);
#     wire g1914 = (inp[488] & inp[516]);
#     wire g1915 = (inp[489] & inp[517]);
#     wire g1916 = (inp[490] & inp[518]);
#     wire g1917 = (inp[491] & inp[519]);
#     wire g1918 = (inp[492] & inp[520]);
#     wire g1919 = (inp[493] & inp[521]);
#     wire g1920 = (inp[494] & inp[522]);
#     wire g1921 = (inp[495] & inp[523]);
#     wire g1922 = (inp[496] & inp[524]);
#     wire g1923 = (inp[497] & inp[525]);
#     wire g1924 = (inp[498] & inp[526]);
#     wire g1925 = (inp[499] & inp[527]);
#     wire g1926 = (inp[500] & inp[528]);
#     wire g1927 = (inp[501] & inp[529]);
#     wire g1928 = (inp[504] & inp[532]);
#     wire g1929 = (inp[505] & inp[533]);
#     wire g1930 = (inp[506] & inp[534]);
#     wire g1931 = (inp[507] & inp[535]);
#     wire g1932 = (inp[508] & inp[536]);
#     wire g1933 = (inp[509] & inp[537]);
#     wire g1934 = (inp[510] & inp[538]);
#     wire g1935 = (inp[511] & inp[539]);
#     wire g1936 = (inp[512] & inp[540]);
#     wire g1937 = (inp[513] & inp[541]);
#     wire g1938 = (inp[514] & inp[542]);
#     wire g1939 = (inp[515] & inp[543]);
#     wire g1940 = (inp[516] & inp[544]);
#     wire g1941 = (inp[517] & inp[545]);
#     wire g1942 = (inp[518] & inp[546]);
#     wire g1943 = (inp[519] & inp[547]);
#     wire g1944 = (inp[520] & inp[548]);
#     wire g1945 = (inp[521] & inp[549]);
#     wire g1946 = (inp[522] & inp[550]);
#     wire g1947 = (inp[523] & inp[551]);
#     wire g1948 = (inp[524] & inp[552]);
#     wire g1949 = (inp[525] & inp[553]);
#     wire g1950 = (inp[526] & inp[554]);
#     wire g1951 = (inp[527] & inp[555]);
#     wire g1952 = (inp[528] & inp[556]);
#     wire g1953 = (inp[529] & inp[557]);
#     wire g1954 = (inp[532] & inp[560]);
#     wire g1955 = (inp[533] & inp[561]);
#     wire g1956 = (inp[534] & inp[562]);
#     wire g1957 = (inp[535] & inp[563]);
#     wire g1958 = (inp[536] & inp[564]);
#     wire g1959 = (inp[537] & inp[565]);
#     wire g1960 = (inp[538] & inp[566]);
#     wire g1961 = (inp[539] & inp[567]);
#     wire g1962 = (inp[540] & inp[568]);
#     wire g1963 = (inp[541] & inp[569]);
#     wire g1964 = (inp[542] & inp[570]);
#     wire g1965 = (inp[543] & inp[571]);
#     wire g1966 = (inp[544] & inp[572]);
#     wire g1967 = (inp[545] & inp[573]);
#     wire g1968 = (inp[546] & inp[574]);
#     wire g1969 = (inp[547] & inp[575]);
#     wire g1970 = (inp[548] & inp[576]);
#     wire g1971 = (inp[549] & inp[577]);
#     wire g1972 = (inp[550] & inp[578]);
#     wire g1973 = (inp[551] & inp[579]);
#     wire g1974 = (inp[552] & inp[580]);
#     wire g1975 = (inp[553] & inp[581]);
#     wire g1976 = (inp[554] & inp[582]);
#     wire g1977 = (inp[555] & inp[583]);
#     wire g1978 = (inp[556] & inp[584]);
#     wire g1979 = (inp[557] & inp[585]);
#     wire g1980 = (inp[560] & inp[588]);
#     wire g1981 = (inp[561] & inp[589]);
#     wire g1982 = (inp[562] & inp[590]);
#     wire g1983 = (inp[563] & inp[591]);
#     wire g1984 = (inp[564] & inp[592]);
#     wire g1985 = (inp[565] & inp[593]);
#     wire g1986 = (inp[566] & inp[594]);
#     wire g1987 = (inp[567] & inp[595]);
#     wire g1988 = (inp[568] & inp[596]);
#     wire g1989 = (inp[569] & inp[597]);
#     wire g1990 = (inp[570] & inp[598]);
#     wire g1991 = (inp[571] & inp[599]);
#     wire g1992 = (inp[572] & inp[600]);
#     wire g1993 = (inp[573] & inp[601]);
#     wire g1994 = (inp[574] & inp[602]);
#     wire g1995 = (inp[575] & inp[603]);
#     wire g1996 = (inp[576] & inp[604]);
#     wire g1997 = (inp[577] & inp[605]);
#     wire g1998 = (inp[578] & inp[606]);
#     wire g1999 = (inp[579] & inp[607]);
#     wire g2000 = (inp[580] & inp[608]);
#     wire g2001 = (inp[581] & inp[609]);
#     wire g2002 = (inp[582] & inp[610]);
#     wire g2003 = (inp[583] & inp[611]);
#     wire g2004 = (inp[584] & inp[612]);
#     wire g2005 = (inp[585] & inp[613]);
#     wire g2006 = (inp[588] & inp[616]);
#     wire g2007 = (inp[589] & inp[617]);
#     wire g2008 = (inp[590] & inp[618]);
#     wire g2009 = (inp[591] & inp[619]);
#     wire g2010 = (inp[592] & inp[620]);
#     wire g2011 = (inp[593] & inp[621]);
#     wire g2012 = (inp[594] & inp[622]);
#     wire g2013 = (inp[595] & inp[623]);
#     wire g2014 = (inp[596] & inp[624]);
#     wire g2015 = (inp[597] & inp[625]);
#     wire g2016 = (inp[598] & inp[626]);
#     wire g2017 = (inp[599] & inp[627]);
#     wire g2018 = (inp[600] & inp[628]);
#     wire g2019 = (inp[601] & inp[629]);
#     wire g2020 = (inp[602] & inp[630]);
#     wire g2021 = (inp[603] & inp[631]);
#     wire g2022 = (inp[604] & inp[632]);
#     wire g2023 = (inp[605] & inp[633]);
#     wire g2024 = (inp[606] & inp[634]);
#     wire g2025 = (inp[607] & inp[635]);
#     wire g2026 = (inp[608] & inp[636]);
#     wire g2027 = (inp[609] & inp[637]);
#     wire g2028 = (inp[610] & inp[638]);
#     wire g2029 = (inp[611] & inp[639]);
#     wire g2030 = (inp[612] & inp[640]);
#     wire g2031 = (inp[613] & inp[641]);
#     wire g2032 = (inp[616] & inp[644]);
#     wire g2033 = (inp[617] & inp[645]);
#     wire g2034 = (inp[618] & inp[646]);
#     wire g2035 = (inp[619] & inp[647]);
#     wire g2036 = (inp[620] & inp[648]);
#     wire g2037 = (inp[621] & inp[649]);
#     wire g2038 = (inp[622] & inp[650]);
#     wire g2039 = (inp[623] & inp[651]);
#     wire g2040 = (inp[624] & inp[652]);
#     wire g2041 = (inp[625] & inp[653]);
#     wire g2042 = (inp[626] & inp[654]);
#     wire g2043 = (inp[627] & inp[655]);
#     wire g2044 = (inp[628] & inp[656]);
#     wire g2045 = (inp[629] & inp[657]);
#     wire g2046 = (inp[630] & inp[658]);
#     wire g2047 = (inp[631] & inp[659]);
#     wire g2048 = (inp[632] & inp[660]);
#     wire g2049 = (inp[633] & inp[661]);
#     wire g2050 = (inp[634] & inp[662]);
#     wire g2051 = (inp[635] & inp[663]);
#     wire g2052 = (inp[636] & inp[664]);
#     wire g2053 = (inp[637] & inp[665]);
#     wire g2054 = (inp[638] & inp[666]);
#     wire g2055 = (inp[639] & inp[667]);
#     wire g2056 = (inp[640] & inp[668]);
#     wire g2057 = (inp[641] & inp[669]);
#     wire g2058 = (inp[644] & inp[672]);
#     wire g2059 = (inp[645] & inp[673]);
#     wire g2060 = (inp[646] & inp[674]);
#     wire g2061 = (inp[647] & inp[675]);
#     wire g2062 = (inp[648] & inp[676]);
#     wire g2063 = (inp[649] & inp[677]);
#     wire g2064 = (inp[650] & inp[678]);
#     wire g2065 = (inp[651] & inp[679]);
#     wire g2066 = (inp[652] & inp[680]);
#     wire g2067 = (inp[653] & inp[681]);
#     wire g2068 = (inp[654] & inp[682]);
#     wire g2069 = (inp[655] & inp[683]);
#     wire g2070 = (inp[656] & inp[684]);
#     wire g2071 = (inp[657] & inp[685]);
#     wire g2072 = (inp[658] & inp[686]);
#     wire g2073 = (inp[659] & inp[687]);
#     wire g2074 = (inp[660] & inp[688]);
#     wire g2075 = (inp[661] & inp[689]);
#     wire g2076 = (inp[662] & inp[690]);
#     wire g2077 = (inp[663] & inp[691]);
#     wire g2078 = (inp[664] & inp[692]);
#     wire g2079 = (inp[665] & inp[693]);
#     wire g2080 = (inp[666] & inp[694]);
#     wire g2081 = (inp[667] & inp[695]);
#     wire g2082 = (inp[668] & inp[696]);
#     wire g2083 = (inp[669] & inp[697]);
#     wire g2084 = (inp[672] & inp[700]);
#     wire g2085 = (inp[673] & inp[701]);
#     wire g2088 = (inp[676] & inp[704]);
#     wire g2089 = (inp[677] & inp[705]);
#     wire g2090 = (inp[678] & inp[706]);
#     wire g2091 = (inp[679] & inp[707]);
#     wire g2092 = (inp[680] & inp[708]);
#     wire g2093 = (inp[681] & inp[709]);
#     wire g2094 = (inp[682] & inp[710]);
#     wire g2095 = (inp[683] & inp[711]);
#     wire g2096 = (inp[684] & inp[712]);
#     wire g2097 = (inp[685] & inp[713]);
#     wire g2098 = (inp[686] & inp[714]);
#     wire g2099 = (inp[687] & inp[715]);
#     wire g2100 = (inp[688] & inp[716]);
#     wire g2101 = (inp[689] & inp[717]);
#     wire g2102 = (inp[690] & inp[718]);
#     wire g2103 = (inp[691] & inp[719]);
#     wire g2106 = (inp[694] & inp[722]);
#     wire g2107 = (inp[695] & inp[723]);
#     wire g2108 = (inp[696] & inp[724]);
#     wire g2109 = (inp[697] & inp[725]);
#     wire g2110 = (inp[700] & inp[728]);
#     wire g2111 = (inp[701] & inp[729]);
#     wire g2114 = (inp[704] & inp[732]);
#     wire g2115 = (inp[705] & inp[733]);
#     wire g2116 = (inp[706] & inp[734]);
#     wire g2117 = (inp[707] & inp[735]);
#     wire g2118 = (inp[708] & inp[736]);
#     wire g2119 = (inp[709] & inp[737]);
#     wire g2120 = (inp[710] & inp[738]);
#     wire g2121 = (inp[711] & inp[739]);
#     wire g2122 = (inp[712] & inp[740]);
#     wire g2123 = (inp[713] & inp[741]);
#     wire g2124 = (inp[714] & inp[742]);
#     wire g2125 = (inp[715] & inp[743]);
#     wire g2126 = (inp[716] & inp[744]);
#     wire g2127 = (inp[717] & inp[745]);
#     wire g2128 = (inp[718] & inp[746]);
#     wire g2129 = (inp[719] & inp[747]);
#     wire g2132 = (inp[722] & inp[750]);
#     wire g2133 = (inp[723] & inp[751]);
#     wire g2134 = (inp[724] & inp[752]);
#     wire g2135 = (inp[725] & inp[753]);
#     wire g2136 = (inp[29] & inp[56]);
#     wire g2137 = (inp[30] & inp[57]);
#     wire g2138 = (inp[31] & inp[58]);
#     wire g2139 = (inp[32] & inp[59]);
#     wire g2144 = (inp[37] & inp[64]);
#     wire g2145 = (inp[38] & inp[65]);
#     wire g2146 = (inp[39] & inp[66]);
#     wire g2147 = (inp[40] & inp[67]);
#     wire g2150 = (inp[43] & inp[70]);
#     wire g2151 = (inp[44] & inp[71]);
#     wire g2152 = (inp[45] & inp[72]);
#     wire g2153 = (inp[46] & inp[73]);
#     wire g2154 = (inp[47] & inp[74]);
#     wire g2155 = (inp[48] & inp[75]);
#     wire g2156 = (inp[49] & inp[76]);
#     wire g2157 = (inp[50] & inp[77]);
#     wire g2158 = (inp[51] & inp[78]);
#     wire g2159 = (inp[52] & inp[79]);
#     wire g2160 = (inp[53] & inp[80]);
#     wire g2161 = (inp[54] & inp[81]);
#     wire g2162 = (inp[57] & inp[84]);
#     wire g2163 = (inp[58] & inp[85]);
#     wire g2164 = (inp[59] & inp[86]);
#     wire g2165 = (inp[60] & inp[87]);
#     wire g2170 = (inp[65] & inp[92]);
#     wire g2171 = (inp[66] & inp[93]);
#     wire g2172 = (inp[67] & inp[94]);
#     wire g2173 = (inp[68] & inp[95]);
#     wire g2176 = (inp[71] & inp[98]);
#     wire g2177 = (inp[72] & inp[99]);
#     wire g2178 = (inp[73] & inp[100]);
#     wire g2179 = (inp[74] & inp[101]);
#     wire g2180 = (inp[75] & inp[102]);
#     wire g2181 = (inp[76] & inp[103]);
#     wire g2182 = (inp[77] & inp[104]);
#     wire g2183 = (inp[78] & inp[105]);
#     wire g2184 = (inp[79] & inp[106]);
#     wire g2185 = (inp[80] & inp[107]);
#     wire g2186 = (inp[81] & inp[108]);
#     wire g2187 = (inp[82] & inp[109]);
#     wire g2188 = (inp[85] & inp[112]);
#     wire g2189 = (inp[86] & inp[113]);
#     wire g2192 = (inp[89] & inp[116]);
#     wire g2193 = (inp[90] & inp[117]);
#     wire g2194 = (inp[91] & inp[118]);
#     wire g2195 = (inp[92] & inp[119]);
#     wire g2196 = (inp[93] & inp[120]);
#     wire g2197 = (inp[94] & inp[121]);
#     wire g2198 = (inp[95] & inp[122]);
#     wire g2199 = (inp[96] & inp[123]);
#     wire g2202 = (inp[99] & inp[126]);
#     wire g2203 = (inp[100] & inp[127]);
#     wire g2204 = (inp[101] & inp[128]);
#     wire g2205 = (inp[102] & inp[129]);
#     wire g2206 = (inp[103] & inp[130]);
#     wire g2207 = (inp[104] & inp[131]);
#     wire g2208 = (inp[105] & inp[132]);
#     wire g2209 = (inp[106] & inp[133]);
#     wire g2210 = (inp[107] & inp[134]);
#     wire g2211 = (inp[108] & inp[135]);
#     wire g2212 = (inp[109] & inp[136]);
#     wire g2213 = (inp[110] & inp[137]);
#     wire g2214 = (inp[113] & inp[140]);
#     wire g2215 = (inp[114] & inp[141]);
#     wire g2218 = (inp[117] & inp[144]);
#     wire g2219 = (inp[118] & inp[145]);
#     wire g2220 = (inp[119] & inp[146]);
#     wire g2221 = (inp[120] & inp[147]);
#     wire g2222 = (inp[121] & inp[148]);
#     wire g2223 = (inp[122] & inp[149]);
#     wire g2224 = (inp[123] & inp[150]);
#     wire g2225 = (inp[124] & inp[151]);
#     wire g2228 = (inp[127] & inp[154]);
#     wire g2229 = (inp[128] & inp[155]);
#     wire g2230 = (inp[129] & inp[156]);
#     wire g2231 = (inp[130] & inp[157]);
#     wire g2232 = (inp[131] & inp[158]);
#     wire g2233 = (inp[132] & inp[159]);
#     wire g2234 = (inp[133] & inp[160]);
#     wire g2235 = (inp[134] & inp[161]);
#     wire g2236 = (inp[135] & inp[162]);
#     wire g2237 = (inp[136] & inp[163]);
#     wire g2238 = (inp[137] & inp[164]);
#     wire g2239 = (inp[138] & inp[165]);
#     wire g2242 = (inp[143] & inp[170]);
#     wire g2243 = (inp[144] & inp[171]);
#     wire g2244 = (inp[145] & inp[172]);
#     wire g2245 = (inp[146] & inp[173]);
#     wire g2246 = (inp[147] & inp[174]);
#     wire g2247 = (inp[148] & inp[175]);
#     wire g2248 = (inp[149] & inp[176]);
#     wire g2249 = (inp[150] & inp[177]);
#     wire g2250 = (inp[151] & inp[178]);
#     wire g2251 = (inp[152] & inp[179]);
#     wire g2252 = (inp[153] & inp[180]);
#     wire g2253 = (inp[154] & inp[181]);
#     wire g2254 = (inp[155] & inp[182]);
#     wire g2255 = (inp[156] & inp[183]);
#     wire g2256 = (inp[157] & inp[184]);
#     wire g2257 = (inp[158] & inp[185]);
#     wire g2258 = (inp[159] & inp[186]);
#     wire g2259 = (inp[160] & inp[187]);
#     wire g2260 = (inp[161] & inp[188]);
#     wire g2261 = (inp[162] & inp[189]);
#     wire g2264 = (inp[165] & inp[192]);
#     wire g2265 = (inp[166] & inp[193]);
#     wire g2268 = (inp[171] & inp[198]);
#     wire g2269 = (inp[172] & inp[199]);
#     wire g2270 = (inp[173] & inp[200]);
#     wire g2271 = (inp[174] & inp[201]);
#     wire g2272 = (inp[175] & inp[202]);
#     wire g2273 = (inp[176] & inp[203]);
#     wire g2274 = (inp[177] & inp[204]);
#     wire g2275 = (inp[178] & inp[205]);
#     wire g2276 = (inp[179] & inp[206]);
#     wire g2277 = (inp[180] & inp[207]);
#     wire g2278 = (inp[181] & inp[208]);
#     wire g2279 = (inp[182] & inp[209]);
#     wire g2280 = (inp[183] & inp[210]);
#     wire g2281 = (inp[184] & inp[211]);
#     wire g2282 = (inp[185] & inp[212]);
#     wire g2283 = (inp[186] & inp[213]);
#     wire g2284 = (inp[187] & inp[214]);
#     wire g2285 = (inp[188] & inp[215]);
#     wire g2286 = (inp[189] & inp[216]);
#     wire g2287 = (inp[190] & inp[217]);
#     wire g2290 = (inp[193] & inp[220]);
#     wire g2291 = (inp[194] & inp[221]);
#     wire g2292 = (inp[197] & inp[224]);
#     wire g2293 = (inp[198] & inp[225]);
#     wire g2294 = (inp[199] & inp[226]);
#     wire g2295 = (inp[200] & inp[227]);
#     wire g2296 = (inp[201] & inp[228]);
#     wire g2297 = (inp[202] & inp[229]);
#     wire g2298 = (inp[203] & inp[230]);
#     wire g2299 = (inp[204] & inp[231]);
#     wire g2300 = (inp[205] & inp[232]);
#     wire g2301 = (inp[206] & inp[233]);
#     wire g2302 = (inp[207] & inp[234]);
#     wire g2303 = (inp[208] & inp[235]);
#     wire g2304 = (inp[209] & inp[236]);
#     wire g2305 = (inp[210] & inp[237]);
#     wire g2306 = (inp[211] & inp[238]);
#     wire g2307 = (inp[212] & inp[239]);
#     wire g2308 = (inp[213] & inp[240]);
#     wire g2309 = (inp[214] & inp[241]);
#     wire g2310 = (inp[215] & inp[242]);
#     wire g2311 = (inp[216] & inp[243]);
#     wire g2314 = (inp[219] & inp[246]);
#     wire g2315 = (inp[220] & inp[247]);
#     wire g2316 = (inp[221] & inp[248]);
#     wire g2317 = (inp[222] & inp[249]);
#     wire g2318 = (inp[225] & inp[252]);
#     wire g2319 = (inp[226] & inp[253]);
#     wire g2320 = (inp[227] & inp[254]);
#     wire g2321 = (inp[228] & inp[255]);
#     wire g2322 = (inp[229] & inp[256]);
#     wire g2323 = (inp[230] & inp[257]);
#     wire g2324 = (inp[231] & inp[258]);
#     wire g2325 = (inp[232] & inp[259]);
#     wire g2326 = (inp[233] & inp[260]);
#     wire g2327 = (inp[234] & inp[261]);
#     wire g2328 = (inp[235] & inp[262]);
#     wire g2329 = (inp[236] & inp[263]);
#     wire g2330 = (inp[237] & inp[264]);
#     wire g2331 = (inp[238] & inp[265]);
#     wire g2332 = (inp[239] & inp[266]);
#     wire g2333 = (inp[240] & inp[267]);
#     wire g2334 = (inp[241] & inp[268]);
#     wire g2335 = (inp[242] & inp[269]);
#     wire g2336 = (inp[243] & inp[270]);
#     wire g2337 = (inp[244] & inp[271]);
#     wire g2340 = (inp[247] & inp[274]);
#     wire g2341 = (inp[248] & inp[275]);
#     wire g2342 = (inp[249] & inp[276]);
#     wire g2343 = (inp[250] & inp[277]);
#     wire g2344 = (inp[253] & inp[280]);
#     wire g2345 = (inp[254] & inp[281]);
#     wire g2346 = (inp[255] & inp[282]);
#     wire g2347 = (inp[256] & inp[283]);
#     wire g2348 = (inp[257] & inp[284]);
#     wire g2349 = (inp[258] & inp[285]);
#     wire g2350 = (inp[259] & inp[286]);
#     wire g2351 = (inp[260] & inp[287]);
#     wire g2352 = (inp[261] & inp[288]);
#     wire g2353 = (inp[262] & inp[289]);
#     wire g2354 = (inp[263] & inp[290]);
#     wire g2355 = (inp[264] & inp[291]);
#     wire g2356 = (inp[265] & inp[292]);
#     wire g2357 = (inp[266] & inp[293]);
#     wire g2360 = (inp[269] & inp[296]);
#     wire g2361 = (inp[270] & inp[297]);
#     wire g2362 = (inp[271] & inp[298]);
#     wire g2363 = (inp[272] & inp[299]);
#     wire g2364 = (inp[273] & inp[300]);
#     wire g2365 = (inp[274] & inp[301]);
#     wire g2368 = (inp[277] & inp[304]);
#     wire g2369 = (inp[278] & inp[305]);
#     wire g2370 = (inp[281] & inp[308]);
#     wire g2371 = (inp[282] & inp[309]);
#     wire g2372 = (inp[283] & inp[310]);
#     wire g2373 = (inp[284] & inp[311]);
#     wire g2374 = (inp[285] & inp[312]);
#     wire g2375 = (inp[286] & inp[313]);
#     wire g2376 = (inp[287] & inp[314]);
#     wire g2377 = (inp[288] & inp[315]);
#     wire g2378 = (inp[289] & inp[316]);
#     wire g2379 = (inp[290] & inp[317]);
#     wire g2380 = (inp[291] & inp[318]);
#     wire g2381 = (inp[292] & inp[319]);
#     wire g2382 = (inp[293] & inp[320]);
#     wire g2383 = (inp[294] & inp[321]);
#     wire g2386 = (inp[297] & inp[324]);
#     wire g2387 = (inp[298] & inp[325]);
#     wire g2388 = (inp[299] & inp[326]);
#     wire g2389 = (inp[300] & inp[327]);
#     wire g2390 = (inp[301] & inp[328]);
#     wire g2391 = (inp[302] & inp[329]);
#     wire g2394 = (inp[305] & inp[332]);
#     wire g2395 = (inp[306] & inp[333]);
#     wire g2396 = (inp[309] & inp[336]);
#     wire g2397 = (inp[310] & inp[337]);
#     wire g2398 = (inp[311] & inp[338]);
#     wire g2399 = (inp[312] & inp[339]);
#     wire g2400 = (inp[313] & inp[340]);
#     wire g2401 = (inp[314] & inp[341]);
#     wire g2402 = (inp[315] & inp[342]);
#     wire g2403 = (inp[316] & inp[343]);
#     wire g2404 = (inp[317] & inp[344]);
#     wire g2405 = (inp[318] & inp[345]);
#     wire g2406 = (inp[319] & inp[346]);
#     wire g2407 = (inp[320] & inp[347]);
#     wire g2408 = (inp[321] & inp[348]);
#     wire g2409 = (inp[322] & inp[349]);
#     wire g2410 = (inp[323] & inp[350]);
#     wire g2411 = (inp[324] & inp[351]);
#     wire g2412 = (inp[325] & inp[352]);
#     wire g2413 = (inp[326] & inp[353]);
#     wire g2414 = (inp[327] & inp[354]);
#     wire g2415 = (inp[328] & inp[355]);
#     wire g2416 = (inp[329] & inp[356]);
#     wire g2417 = (inp[330] & inp[357]);
#     wire g2418 = (inp[331] & inp[358]);
#     wire g2419 = (inp[332] & inp[359]);
#     wire g2420 = (inp[333] & inp[360]);
#     wire g2421 = (inp[334] & inp[361]);
#     wire g2422 = (inp[337] & inp[364]);
#     wire g2423 = (inp[338] & inp[365]);
#     wire g2424 = (inp[339] & inp[366]);
#     wire g2425 = (inp[340] & inp[367]);
#     wire g2426 = (inp[341] & inp[368]);
#     wire g2427 = (inp[342] & inp[369]);
#     wire g2428 = (inp[343] & inp[370]);
#     wire g2429 = (inp[344] & inp[371]);
#     wire g2430 = (inp[345] & inp[372]);
#     wire g2431 = (inp[346] & inp[373]);
#     wire g2432 = (inp[347] & inp[374]);
#     wire g2433 = (inp[348] & inp[375]);
#     wire g2434 = (inp[349] & inp[376]);
#     wire g2435 = (inp[350] & inp[377]);
#     wire g2436 = (inp[351] & inp[378]);
#     wire g2437 = (inp[352] & inp[379]);
#     wire g2438 = (inp[353] & inp[380]);
#     wire g2439 = (inp[354] & inp[381]);
#     wire g2440 = (inp[355] & inp[382]);
#     wire g2441 = (inp[356] & inp[383]);
#     wire g2442 = (inp[357] & inp[384]);
#     wire g2443 = (inp[358] & inp[385]);
#     wire g2444 = (inp[359] & inp[386]);
#     wire g2445 = (inp[360] & inp[387]);
#     wire g2446 = (inp[361] & inp[388]);
#     wire g2447 = (inp[362] & inp[389]);
#     wire g2448 = (inp[365] & inp[392]);
#     wire g2449 = (inp[366] & inp[393]);
#     wire g2450 = (inp[367] & inp[394]);
#     wire g2451 = (inp[368] & inp[395]);
#     wire g2452 = (inp[369] & inp[396]);
#     wire g2453 = (inp[370] & inp[397]);
#     wire g2454 = (inp[371] & inp[398]);
#     wire g2455 = (inp[372] & inp[399]);
#     wire g2456 = (inp[373] & inp[400]);
#     wire g2457 = (inp[374] & inp[401]);
#     wire g2458 = (inp[375] & inp[402]);
#     wire g2459 = (inp[376] & inp[403]);
#     wire g2460 = (inp[377] & inp[404]);
#     wire g2461 = (inp[378] & inp[405]);
#     wire g2462 = (inp[379] & inp[406]);
#     wire g2463 = (inp[380] & inp[407]);
#     wire g2464 = (inp[381] & inp[408]);
#     wire g2465 = (inp[382] & inp[409]);
#     wire g2466 = (inp[383] & inp[410]);
#     wire g2467 = (inp[384] & inp[411]);
#     wire g2468 = (inp[385] & inp[412]);
#     wire g2469 = (inp[386] & inp[413]);
#     wire g2472 = (inp[389] & inp[416]);
#     wire g2473 = (inp[390] & inp[417]);
#     wire g2474 = (inp[393] & inp[420]);
#     wire g2475 = (inp[394] & inp[421]);
#     wire g2476 = (inp[395] & inp[422]);
#     wire g2477 = (inp[396] & inp[423]);
#     wire g2478 = (inp[397] & inp[424]);
#     wire g2479 = (inp[398] & inp[425]);
#     wire g2480 = (inp[399] & inp[426]);
#     wire g2481 = (inp[400] & inp[427]);
#     wire g2482 = (inp[401] & inp[428]);
#     wire g2483 = (inp[402] & inp[429]);
#     wire g2484 = (inp[403] & inp[430]);
#     wire g2485 = (inp[404] & inp[431]);
#     wire g2486 = (inp[405] & inp[432]);
#     wire g2487 = (inp[406] & inp[433]);
#     wire g2488 = (inp[407] & inp[434]);
#     wire g2489 = (inp[408] & inp[435]);
#     wire g2490 = (inp[409] & inp[436]);
#     wire g2491 = (inp[410] & inp[437]);
#     wire g2492 = (inp[411] & inp[438]);
#     wire g2493 = (inp[412] & inp[439]);
#     wire g2494 = (inp[413] & inp[440]);
#     wire g2495 = (inp[414] & inp[441]);
#     wire g2498 = (inp[417] & inp[444]);
#     wire g2499 = (inp[418] & inp[445]);
#     wire g2500 = (inp[421] & inp[448]);
#     wire g2501 = (inp[422] & inp[449]);
#     wire g2502 = (inp[423] & inp[450]);
#     wire g2503 = (inp[424] & inp[451]);
#     wire g2504 = (inp[425] & inp[452]);
#     wire g2505 = (inp[426] & inp[453]);
#     wire g2506 = (inp[427] & inp[454]);
#     wire g2507 = (inp[428] & inp[455]);
#     wire g2508 = (inp[429] & inp[456]);
#     wire g2509 = (inp[430] & inp[457]);
#     wire g2510 = (inp[431] & inp[458]);
#     wire g2511 = (inp[432] & inp[459]);
#     wire g2512 = (inp[433] & inp[460]);
#     wire g2513 = (inp[434] & inp[461]);
#     wire g2514 = (inp[435] & inp[462]);
#     wire g2515 = (inp[436] & inp[463]);
#     wire g2516 = (inp[437] & inp[464]);
#     wire g2517 = (inp[438] & inp[465]);
#     wire g2518 = (inp[439] & inp[466]);
#     wire g2519 = (inp[440] & inp[467]);
#     wire g2520 = (inp[441] & inp[468]);
#     wire g2521 = (inp[442] & inp[469]);
#     wire g2522 = (inp[443] & inp[470]);
#     wire g2523 = (inp[444] & inp[471]);
#     wire g2524 = (inp[445] & inp[472]);
#     wire g2525 = (inp[446] & inp[473]);
#     wire g2526 = (inp[449] & inp[476]);
#     wire g2527 = (inp[450] & inp[477]);
#     wire g2528 = (inp[451] & inp[478]);
#     wire g2529 = (inp[452] & inp[479]);
#     wire g2530 = (inp[453] & inp[480]);
#     wire g2531 = (inp[454] & inp[481]);
#     wire g2532 = (inp[455] & inp[482]);
#     wire g2533 = (inp[456] & inp[483]);
#     wire g2534 = (inp[457] & inp[484]);
#     wire g2535 = (inp[458] & inp[485]);
#     wire g2536 = (inp[459] & inp[486]);
#     wire g2537 = (inp[460] & inp[487]);
#     wire g2538 = (inp[461] & inp[488]);
#     wire g2539 = (inp[462] & inp[489]);
#     wire g2540 = (inp[463] & inp[490]);
#     wire g2541 = (inp[464] & inp[491]);
#     wire g2542 = (inp[465] & inp[492]);
#     wire g2543 = (inp[466] & inp[493]);
#     wire g2544 = (inp[467] & inp[494]);
#     wire g2545 = (inp[468] & inp[495]);
#     wire g2546 = (inp[469] & inp[496]);
#     wire g2547 = (inp[470] & inp[497]);
#     wire g2548 = (inp[471] & inp[498]);
#     wire g2549 = (inp[472] & inp[499]);
#     wire g2550 = (inp[473] & inp[500]);
#     wire g2551 = (inp[474] & inp[501]);
#     wire g2552 = (inp[477] & inp[504]);
#     wire g2553 = (inp[478] & inp[505]);
#     wire g2554 = (inp[479] & inp[506]);
#     wire g2555 = (inp[480] & inp[507]);
#     wire g2556 = (inp[481] & inp[508]);
#     wire g2557 = (inp[482] & inp[509]);
#     wire g2558 = (inp[483] & inp[510]);
#     wire g2559 = (inp[484] & inp[511]);
#     wire g2560 = (inp[485] & inp[512]);
#     wire g2561 = (inp[486] & inp[513]);
#     wire g2562 = (inp[487] & inp[514]);
#     wire g2563 = (inp[488] & inp[515]);
#     wire g2564 = (inp[489] & inp[516]);
#     wire g2565 = (inp[490] & inp[517]);
#     wire g2566 = (inp[491] & inp[518]);
#     wire g2567 = (inp[492] & inp[519]);
#     wire g2568 = (inp[493] & inp[520]);
#     wire g2569 = (inp[494] & inp[521]);
#     wire g2570 = (inp[495] & inp[522]);
#     wire g2571 = (inp[496] & inp[523]);
#     wire g2572 = (inp[497] & inp[524]);
#     wire g2573 = (inp[498] & inp[525]);
#     wire g2574 = (inp[499] & inp[526]);
#     wire g2575 = (inp[500] & inp[527]);
#     wire g2578 = (inp[505] & inp[532]);
#     wire g2579 = (inp[506] & inp[533]);
#     wire g2580 = (inp[507] & inp[534]);
#     wire g2581 = (inp[508] & inp[535]);
#     wire g2582 = (inp[509] & inp[536]);
#     wire g2583 = (inp[510] & inp[537]);
#     wire g2584 = (inp[511] & inp[538]);
#     wire g2585 = (inp[512] & inp[539]);
#     wire g2586 = (inp[513] & inp[540]);
#     wire g2587 = (inp[514] & inp[541]);
#     wire g2588 = (inp[515] & inp[542]);
#     wire g2589 = (inp[516] & inp[543]);
#     wire g2590 = (inp[517] & inp[544]);
#     wire g2591 = (inp[518] & inp[545]);
#     wire g2592 = (inp[519] & inp[546]);
#     wire g2593 = (inp[520] & inp[547]);
#     wire g2594 = (inp[521] & inp[548]);
#     wire g2595 = (inp[522] & inp[549]);
#     wire g2596 = (inp[523] & inp[550]);
#     wire g2597 = (inp[524] & inp[551]);
#     wire g2598 = (inp[525] & inp[552]);
#     wire g2599 = (inp[526] & inp[553]);
#     wire g2600 = (inp[527] & inp[554]);
#     wire g2601 = (inp[528] & inp[555]);
#     wire g2604 = (inp[533] & inp[560]);
#     wire g2605 = (inp[534] & inp[561]);
#     wire g2606 = (inp[535] & inp[562]);
#     wire g2607 = (inp[536] & inp[563]);
#     wire g2608 = (inp[537] & inp[564]);
#     wire g2609 = (inp[538] & inp[565]);
#     wire g2610 = (inp[539] & inp[566]);
#     wire g2611 = (inp[540] & inp[567]);
#     wire g2612 = (inp[541] & inp[568]);
#     wire g2613 = (inp[542] & inp[569]);
#     wire g2614 = (inp[543] & inp[570]);
#     wire g2615 = (inp[544] & inp[571]);
#     wire g2616 = (inp[545] & inp[572]);
#     wire g2617 = (inp[546] & inp[573]);
#     wire g2618 = (inp[547] & inp[574]);
#     wire g2619 = (inp[548] & inp[575]);
#     wire g2620 = (inp[549] & inp[576]);
#     wire g2621 = (inp[550] & inp[577]);
#     wire g2622 = (inp[551] & inp[578]);
#     wire g2623 = (inp[552] & inp[579]);
#     wire g2628 = (inp[557] & inp[584]);
#     wire g2629 = (inp[558] & inp[585]);
#     wire g2630 = (inp[561] & inp[588]);
#     wire g2631 = (inp[562] & inp[589]);
#     wire g2632 = (inp[563] & inp[590]);
#     wire g2633 = (inp[564] & inp[591]);
#     wire g2634 = (inp[565] & inp[592]);
#     wire g2635 = (inp[566] & inp[593]);
#     wire g2636 = (inp[567] & inp[594]);
#     wire g2637 = (inp[568] & inp[595]);
#     wire g2638 = (inp[569] & inp[596]);
#     wire g2639 = (inp[570] & inp[597]);
#     wire g2640 = (inp[571] & inp[598]);
#     wire g2641 = (inp[572] & inp[599]);
#     wire g2642 = (inp[573] & inp[600]);
#     wire g2643 = (inp[574] & inp[601]);
#     wire g2644 = (inp[575] & inp[602]);
#     wire g2645 = (inp[576] & inp[603]);
#     wire g2646 = (inp[577] & inp[604]);
#     wire g2647 = (inp[578] & inp[605]);
#     wire g2648 = (inp[579] & inp[606]);
#     wire g2649 = (inp[580] & inp[607]);
#     wire g2654 = (inp[585] & inp[612]);
#     wire g2655 = (inp[586] & inp[613]);
#     wire g2658 = (inp[591] & inp[618]);
#     wire g2659 = (inp[592] & inp[619]);
#     wire g2662 = (inp[595] & inp[622]);
#     wire g2663 = (inp[596] & inp[623]);
#     wire g2664 = (inp[597] & inp[624]);
#     wire g2665 = (inp[598] & inp[625]);
#     wire g2666 = (inp[599] & inp[626]);
#     wire g2667 = (inp[600] & inp[627]);
#     wire g2668 = (inp[601] & inp[628]);
#     wire g2669 = (inp[602] & inp[629]);
#     wire g2670 = (inp[603] & inp[630]);
#     wire g2671 = (inp[604] & inp[631]);
#     wire g2672 = (inp[605] & inp[632]);
#     wire g2673 = (inp[606] & inp[633]);
#     wire g2676 = (inp[609] & inp[636]);
#     wire g2677 = (inp[610] & inp[637]);
#     wire g2678 = (inp[611] & inp[638]);
#     wire g2679 = (inp[612] & inp[639]);
#     wire g2684 = (inp[619] & inp[646]);
#     wire g2685 = (inp[620] & inp[647]);
#     wire g2688 = (inp[623] & inp[650]);
#     wire g2689 = (inp[624] & inp[651]);
#     wire g2690 = (inp[625] & inp[652]);
#     wire g2691 = (inp[626] & inp[653]);
#     wire g2692 = (inp[627] & inp[654]);
#     wire g2693 = (inp[628] & inp[655]);
#     wire g2694 = (inp[629] & inp[656]);
#     wire g2695 = (inp[630] & inp[657]);
#     wire g2696 = (inp[631] & inp[658]);
#     wire g2697 = (inp[632] & inp[659]);
#     wire g2698 = (inp[633] & inp[660]);
#     wire g2699 = (inp[634] & inp[661]);
#     wire g2702 = (inp[637] & inp[664]);
#     wire g2703 = (inp[638] & inp[665]);
#     wire g2704 = (inp[639] & inp[666]);
#     wire g2705 = (inp[640] & inp[667]);
#     wire g2708 = (inp[645] & inp[672]);
#     wire g2709 = (inp[646] & inp[673]);
#     wire g2712 = (inp[649] & inp[676]);
#     wire g2713 = (inp[650] & inp[677]);
#     wire g2714 = (inp[651] & inp[678]);
#     wire g2715 = (inp[652] & inp[679]);
#     wire g2716 = (inp[653] & inp[680]);
#     wire g2717 = (inp[654] & inp[681]);
#     wire g2718 = (inp[655] & inp[682]);
#     wire g2719 = (inp[656] & inp[683]);
#     wire g2722 = (inp[659] & inp[686]);
#     wire g2723 = (inp[660] & inp[687]);
#     wire g2724 = (inp[661] & inp[688]);
#     wire g2725 = (inp[662] & inp[689]);
#     wire g2726 = (inp[663] & inp[690]);
#     wire g2727 = (inp[664] & inp[691]);
#     wire g2728 = (inp[665] & inp[692]);
#     wire g2729 = (inp[666] & inp[693]);
#     wire g2730 = (inp[667] & inp[694]);
#     wire g2731 = (inp[668] & inp[695]);
#     wire g2732 = (inp[669] & inp[696]);
#     wire g2733 = (inp[670] & inp[697]);
#     wire g2734 = (inp[673] & inp[700]);
#     wire g2735 = (inp[674] & inp[701]);
#     wire g2738 = (inp[677] & inp[704]);
#     wire g2739 = (inp[678] & inp[705]);
#     wire g2740 = (inp[679] & inp[706]);
#     wire g2741 = (inp[680] & inp[707]);
#     wire g2742 = (inp[681] & inp[708]);
#     wire g2743 = (inp[682] & inp[709]);
#     wire g2744 = (inp[683] & inp[710]);
#     wire g2745 = (inp[684] & inp[711]);
#     wire g2748 = (inp[687] & inp[714]);
#     wire g2749 = (inp[688] & inp[715]);
#     wire g2750 = (inp[689] & inp[716]);
#     wire g2751 = (inp[690] & inp[717]);
#     wire g2752 = (inp[691] & inp[718]);
#     wire g2753 = (inp[692] & inp[719]);
#     wire g2754 = (inp[693] & inp[720]);
#     wire g2755 = (inp[694] & inp[721]);
#     wire g2756 = (inp[695] & inp[722]);
#     wire g2757 = (inp[696] & inp[723]);
#     wire g2758 = (inp[697] & inp[724]);
#     wire g2759 = (inp[698] & inp[725]);
#     wire g2760 = (inp[701] & inp[728]);
#     wire g2761 = (inp[702] & inp[729]);
# ...
#     assign raw[3525] = g11484;
#     assign raw[3526] = g13702;
#     assign raw[3527] = g16956;
#     assign raw[3528] = g11177;
#     assign raw[3529] = g11189;
#     assign raw[3530] = g11433;
#     assign raw[3531] = g11258;
#     assign raw[3532] = g10940;
#     assign raw[3533] = g13302;
#     assign raw[3534] = g11859;
#     assign raw[3535] = g14334;
#     assign raw[3536] = g11482;
#     assign raw[3537] = g11096;
#     assign raw[3538] = g12385;
#     assign raw[3539] = g12485;
#     assign raw[3540] = g10951;
#     assign raw[3541] = g15942;
#     assign raw[3542] = g11136;
#     assign raw[3543] = g11386;
#     assign raw[3544] = g12314;
#     assign raw[3545] = g17269;
#     assign raw[3546] = g11474;
#     assign raw[3547] = g15620;
#     assign raw[3548] = g14126;
#     assign raw[3549] = g10930;
#     assign raw[3550] = g16215;
#     assign raw[3551] = g10944;
#     assign raw[3552] = g15391;
#     assign raw[3553] = g11885;
#     assign raw[3554] = g11025;
#     assign raw[3555] = g11280;
#     assign raw[3556] = g11191;
#     assign raw[3557] = g13379;
#     assign raw[3558] = g11860;
#     assign raw[3559] = g11033;
#     assign raw[3560] = g14123;
#     assign raw[3561] = g13678;
#     assign raw[3562] = g16132;
#     assign raw[3563] = g11182;
#     assign raw[3564] = g12499;
#     assign raw[3565] = g15943;
#     assign raw[3566] = g11222;
#     assign raw[3567] = g11013;
#     assign raw[3568] = g10955;
#     assign raw[3569] = g11083;
#     assign raw[3570] = g13834;
#     assign raw[3571] = g11079;
#     assign raw[3572] = g11231;
#     assign raw[3573] = g14091;
#     assign raw[3574] = g14887;
#     assign raw[3575] = g12525;
#     assign raw[3576] = g12509;
#     assign raw[3577] = g15392;
#     assign raw[3578] = g11911;
#     assign raw[3579] = g15393;
#     assign raw[3580] = g16133;
#     assign raw[3581] = g14889;
#     assign raw[3582] = g15621;
#     assign raw[3583] = g12608;
#     assign raw[3584] = g16584;
#     assign raw[3585] = g11148;
#     assign raw[3586] = g15944;
#     assign raw[3587] = g16134;
#     assign raw[3588] = g13623;
#     assign raw[3589] = g17074;
#     assign raw[3590] = g11038;
#     assign raw[3591] = g11390;
#     assign raw[3592] = g15394;
#     assign raw[3593] = g11626;
#     assign raw[3594] = g16585;
#     assign raw[3595] = g14666;
#     assign raw[3596] = g11179;
#     assign raw[3597] = g11105;
#     assign raw[3598] = g16957;
#     assign raw[3599] = g16586;
#     assign raw[3600] = g15945;
#     assign raw[3601] = g15946;
#     assign raw[3602] = g16135;
#     assign raw[3603] = g16958;
#     assign raw[3604] = g12249;
#     assign raw[3605] = g11172;
#     assign raw[3606] = g14996;
#     assign raw[3607] = g15622;
#     assign raw[3608] = g12525;
#     assign raw[3609] = g12612;
#     assign raw[3610] = g14500;
#     assign raw[3611] = g11023;
#     assign raw[3612] = g14140;
#     assign raw[3613] = g11248;
#     assign raw[3614] = g13304;
#     assign raw[3615] = g11120;
#     assign raw[3616] = g15395;
#     assign raw[3617] = g14312;
#     assign raw[3618] = g15396;
#     assign raw[3619] = g14337;
#     assign raw[3620] = g14478;
#     assign raw[3621] = g11005;
#     assign raw[3622] = g11256;
#     assign raw[3623] = g14959;
#     assign raw[3624] = g15947;
#     assign raw[3625] = g16136;
#     assign raw[3626] = g14899;
#     assign raw[3627] = g11222;
#     assign raw[3628] = g13673;
#     assign raw[3629] = g15623;
#     assign raw[3630] = g13940;
#     assign raw[3631] = g16587;
#     assign raw[3632] = g17189;
#     assign raw[3633] = g11126;
#     assign raw[3634] = g10996;
#     assign raw[3635] = g13670;
#     assign raw[3636] = g11225;
#     assign raw[3637] = g16137;
#     assign raw[3638] = g12108;
#     assign raw[3639] = g11488;
#     assign raw[3640] = g12428;
#     assign raw[3641] = g16588;
#     assign raw[3642] = g11161;
#     assign raw[3643] = g17078;
#     assign raw[3644] = g15948;
#     assign raw[3645] = g11174;
#     assign raw[3646] = g11086;
#     assign raw[3647] = g11136;
#     assign raw[3648] = g15397;
#     assign raw[3649] = g11132;
#     assign raw[3650] = g14247;
#     assign raw[3651] = g10949;
#     assign raw[3652] = g11861;
#     assign raw[3653] = g15624;
#     assign raw[3654] = g11180;
#     assign raw[3655] = g15063;
#     assign raw[3656] = g13885;
#     assign raw[3657] = g12277;
#     assign raw[3658] = g14082;
#     assign raw[3659] = g12613;
#     assign raw[3660] = g14229;
#     assign raw[3661] = g12423;
#     assign raw[3662] = g14196;
#     assign raw[3663] = g11126;
#     assign raw[3664] = g11014;
#     assign raw[3665] = g14995;
#     assign raw[3666] = g13903;
#     assign raw[3667] = g11092;
#     assign raw[3668] = g17079;
#     assign raw[3669] = g12472;
#     assign raw[3670] = g15949;
#     assign raw[3671] = g13862;
#     assign raw[3672] = g12574;
#     assign raw[3673] = g10985;
#     assign raw[3674] = g12551;
#     assign raw[3675] = g11074;
#     assign raw[3676] = g11259;
#     assign raw[3677] = g11859;
#     assign raw[3678] = g11087;
#     assign raw[3679] = g11103;
#     assign raw[3680] = g11075;
#     assign raw[3681] = g11513;
#     assign raw[3682] = g11419;
#     assign raw[3683] = g16138;
#     assign raw[3684] = g11294;
#     assign raw[3685] = g10995;
#     assign raw[3686] = g16589;
#     assign raw[3687] = g14342;
#     assign raw[3688] = g11449;
#     assign raw[3689] = g15625;
#     assign raw[3690] = g16959;
#     assign raw[3691] = g15398;
#     assign raw[3692] = g15626;
#     assign raw[3693] = g14494;
#     assign raw[3694] = g16590;
#     assign raw[3695] = g11511;
#     assign raw[3696] = g16139;
#     assign raw[3697] = g11173;
#     assign raw[3698] = g14729;
#     assign raw[3699] = g11124;
#     assign raw[3700] = g11222;
#     assign raw[3701] = g11083;
#     assign raw[3702] = g16591;
#     assign raw[3703] = g11834;
#     assign raw[3704] = g10999;
#     assign raw[3705] = g11576;
#     assign raw[3706] = g11084;
#     assign raw[3707] = g11169;
#     assign raw[3708] = g17270;
#     assign raw[3709] = g16592;
#     assign raw[3710] = g16593;
#     assign raw[3711] = g11519;
#     assign raw[3712] = g11596;
#     assign raw[3713] = g12356;
#     assign raw[3714] = g15950;
#     assign raw[3715] = g16140;
#     assign raw[3716] = g10978;
#     assign raw[3717] = g13666;
#     assign raw[3718] = g16960;
#     assign raw[3719] = g11214;
#     assign raw[3720] = g11456;
#     assign raw[3721] = g12601;
#     assign raw[3722] = g12310;
#     assign raw[3723] = g10925;
#     assign raw[3724] = g16961;
#     assign raw[3725] = g15399;
#     assign raw[3726] = g12608;
#     assign raw[3727] = g11140;
#     assign raw[3728] = g11437;
#     assign raw[3729] = g12523;
#     assign raw[3730] = g16962;
#     assign raw[3731] = g16594;
#     assign raw[3732] = g14219;
#     assign raw[3733] = g12577;
#     assign raw[3734] = g12545;
#     assign raw[3735] = g14414;
#     assign raw[3736] = g11018;
#     assign raw[3737] = g15951;
#     assign raw[3738] = g16963;
#     assign raw[3739] = g11162;
#     assign raw[3740] = g11019;
#     assign raw[3741] = g11168;
#     assign raw[3742] = g11479;
#     assign raw[3743] = g15627;
#     assign raw[3744] = g16141;
#     assign raw[3745] = g15952;
#     assign raw[3746] = g16595;
#     assign raw[3747] = g15953;
#     assign raw[3748] = g14077;
#     assign raw[3749] = g15628;
#     assign raw[3750] = g15400;
#     assign raw[3751] = g12557;
#     assign raw[3752] = g15629;
#     assign raw[3753] = g10930;
#     assign raw[3754] = g12431;
#     assign raw[3755] = g11087;
#     assign raw[3756] = g12291;
#     assign raw[3757] = g15401;
#     assign raw[3758] = g15954;
#     assign raw[3759] = g11173;
#     assign raw[3760] = g14960;
#     assign raw[3761] = g10977;
#     assign raw[3762] = g10989;
#     assign raw[3763] = g11872;
#     assign raw[3764] = g16142;
#     assign raw[3765] = g16964;
#     assign raw[3766] = g11167;
#     assign raw[3767] = g11204;
#     assign raw[3768] = g11538;
#     assign raw[3769] = g12490;
#     assign raw[3770] = g11188;
#     assign raw[3771] = g11496;
#     assign raw[3772] = g10980;
#     assign raw[3773] = g10981;
#     assign raw[3774] = g13662;
#     assign raw[3775] = g11031;
#     assign raw[3776] = g16596;
#     assign raw[3777] = g12593;
#     assign raw[3778] = g11447;
#     assign raw[3779] = g11041;
#     assign raw[3780] = g11415;
#     assign raw[3781] = g11615;
#     assign raw[3782] = g16597;
#     assign raw[3783] = g12114;
#     assign raw[3784] = g13835;
#     assign raw[3785] = g16143;
#     assign raw[3786] = g11063;
#     assign raw[3787] = g14650;
#     assign raw[3788] = g11626;
#     assign raw[3789] = g11392;
#     assign raw[3790] = g11192;
#     assign raw[3791] = g16144;
#     assign raw[3792] = g13920;
#     assign raw[3793] = g16598;
#     assign raw[3794] = g16145;
#     assign raw[3795] = g14107;
#     assign raw[3796] = g15630;
#     assign raw[3797] = g15955;
#     assign raw[3798] = g11096;
#     assign raw[3799] = g11378;
#     assign raw[3800] = g12455;
#     assign raw[3801] = g11247;
#     assign raw[3802] = g15956;
#     assign raw[3803] = g16146;
#     assign raw[3804] = g15402;
#     assign raw[3805] = g11247;
#     assign raw[3806] = g10986;
#     assign raw[3807] = g12342;
#     assign raw[3808] = g14264;
#     assign raw[3809] = g15050;
#     assign raw[3810] = g16599;
#     assign raw[3811] = g10979;
#     assign raw[3812] = g11416;
#     assign raw[3813] = g10933;
#     assign raw[3814] = g11548;
#     assign raw[3815] = g12539;
#     assign raw[3816] = g14263;
#     assign raw[3817] = g16965;
#     assign raw[3818] = g16600;
#     assign raw[3819] = g15957;
#     assign raw[3820] = g16601;
#     assign raw[3821] = g13419;
#     assign raw[3822] = g11936;
#     assign raw[3823] = g16147;
#     assign raw[3824] = g15306;
#     assign raw[3825] = g11807;
#     assign raw[3826] = g15958;
#     assign raw[3827] = g16602;
#     assign raw[3828] = g16148;
#     assign raw[3829] = g10992;
#     assign raw[3830] = g14117;
#     assign raw[3831] = g15631;
#     assign raw[3832] = g15959;
#     assign raw[3833] = g12381;
#     assign raw[3834] = g15960;
#     assign raw[3835] = g11158;
#     assign raw[3836] = g10993;
#     assign raw[3837] = g10950;
#     assign raw[3838] = g13926;
#     assign raw[3839] = g17080;
#     assign raw[3840] = g16149;
#     assign raw[3841] = g10934;
#     assign raw[3842] = g11252;
#     assign raw[3843] = g11245;
#     assign raw[3844] = g11120;
#     assign raw[3845] = g16603;
#     assign raw[3846] = g11189;
#     assign raw[3847] = g11152;
#     assign raw[3848] = g12083;
#     assign raw[3849] = g14963;
#     assign raw[3850] = g11415;
#     assign raw[3851] = g12538;
#     assign raw[3852] = g10940;
#     assign raw[3853] = g16966;
#     assign raw[3854] = g16967;
#     assign raw[3855] = g16968;
#     assign raw[3856] = g11280;
#     assign raw[3857] = g10985;
#     assign raw[3858] = g15003;
#     assign raw[3859] = g16604;
#     assign raw[3860] = g11056;
#     assign raw[3861] = g16969;
#     assign raw[3862] = g14695;
#     assign raw[3863] = g14631;
#     assign raw[3864] = g15961;
#     assign raw[3865] = g14319;
#     assign raw[3866] = g14186;
#     assign raw[3867] = g11070;
#     assign raw[3868] = g14355;
#     assign raw[3869] = g12538;
#     assign raw[3870] = g15962;
#     assign raw[3871] = g12501;
#     assign raw[3872] = g11015;
#     assign raw[3873] = g16605;
#     assign raw[3874] = g11433;
#     assign raw[3875] = g11517;
#     assign raw[3876] = g11064;
#     assign raw[3877] = g10993;
#     assign raw[3878] = g10935;
#     assign raw[3879] = g15963;
#     assign raw[3880] = g15632;
#     assign raw[3881] = g11029;
#     assign raw[3882] = g12119;
#     assign raw[3883] = g16150;
#     assign raw[3884] = g10990;
#     assign raw[3885] = g11131;
#     assign raw[3886] = g15964;
#     assign raw[3887] = g15965;
#     assign raw[3888] = g12114;
#     assign raw[3889] = g14101;
#     assign raw[3890] = g15633;
#     assign raw[3891] = g11179;
#     assign raw[3892] = g11009;
#     assign raw[3893] = g10949;
#     assign raw[3894] = g11456;
#     assign raw[3895] = g16606;
#     assign raw[3896] = g14321;
#     assign raw[3897] = g11041;
#     assign raw[3898] = g14876;
#     assign raw[3899] = g15314;
#     assign raw[3900] = g11149;
#     assign raw[3901] = g12374;
#     assign raw[3902] = g15634;
#     assign raw[3903] = g12493;
#     assign raw[3904] = g16151;
#     assign raw[3905] = g13842;
#     assign raw[3906] = g17190;
#     assign raw[3907] = g11006;
#     assign raw[3908] = g16607;
#     assign raw[3909] = g11491;
#     assign raw[3910] = g16608;
#     assign raw[3911] = g11148;
#     assign raw[3912] = g11499;
#     assign raw[3913] = g11085;
#     assign raw[3914] = g15403;
#     assign raw[3915] = g17082;
#     assign raw[3916] = g14097;
#     assign raw[3917] = g17192;
#     assign raw[3918] = g13692;
#     assign raw[3919] = g11079;
#     assign raw[3920] = g13857;
#     assign raw[3921] = g15161;
#     assign raw[3922] = g11236;
#     assign raw[3923] = g12472;
#     assign raw[3924] = g14269;
#     assign raw[3925] = g15635;
#     assign raw[3926] = g16152;
#     assign raw[3927] = g17082;
#     assign raw[3928] = g16609;
#     assign raw[3929] = g11872;
#     assign raw[3930] = g14153;
#     assign raw[3931] = g11393;
#     assign raw[3932] = g11065;
#     assign raw[3933] = g17083;
#     assign raw[3934] = g12362;
#     assign raw[3935] = g11012;
#     assign raw[3936] = g15636;
#     assign raw[3937] = g10998;
#     assign raw[3938] = g14636;
#     assign raw[3939] = g10939;
#     assign raw[3940] = g16153;
#     assign raw[3941] = g12492;
#     assign raw[3942] = g11415;
#     assign raw[3943] = g11535;
#     assign raw[3944] = g14720;
#     assign raw[3945] = g11088;
#     assign raw[3946] = g11294;
#     assign raw[3947] = g17078;
#     assign raw[3948] = g11104;
#     assign raw[3949] = g12382;
#     assign raw[3950] = g16216;
#     assign raw[3951] = g11516;
#     assign raw[3952] = g16154;
#     assign raw[3953] = g10975;
#     assign raw[3954] = g14090;
#     assign raw[3955] = g11091;
#     assign raw[3956] = g13900;
#     assign raw[3957] = g12430;
#     assign raw[3958] = g12574;
#     assign raw[3959] = g16970;
#     assign raw[3960] = g11378;
#     assign raw[3961] = g11773;
#     assign raw[3962] = g11913;
#     assign raw[3963] = g11089;
#     assign raw[3964] = g12123;
#     assign raw[3965] = g11428;
#     assign raw[3966] = g16155;
#     assign raw[3967] = g15966;
#     assign raw[3968] = g12587;
#     assign raw[3969] = g16610;
#     assign raw[3970] = g10967;
#     assign raw[3971] = g13314;
#     assign raw[3972] = g16611;
#     assign raw[3973] = g15181;
#     assign raw[3974] = g11120;
#     assign raw[3975] = g11110;
#     assign raw[3976] = g16156;
#     assign raw[3977] = g16157;
#     assign raw[3978] = g11294;
#     assign raw[3979] = g11224;
#     assign raw[3980] = g12563;
#     assign raw[3981] = g11807;
#     assign raw[3982] = g12533;
#     assign raw[3983] = g15637;
#     assign raw[3984] = g15638;
#     assign raw[3985] = g12573;
#     assign raw[3986] = g13840;
#     assign raw[3987] = g16158;
#     assign raw[3988] = g10957;
#     assign raw[3989] = g12437;
#     assign raw[3990] = g16159;
#     assign raw[3991] = g12350;
#     assign raw[3992] = g14677;
#     assign raw[3993] = g16612;
#     assign raw[3994] = g11473;
#     assign raw[3995] = g16160;
#
#     // --- outputs (behavioral - synthesizer maps to carry chain) ---
#     integer s_0, s_1, s_2, s_3, s_4, s_5, s_6, s_7, s_8, s_9, i;
#     always @(*) begin
#         s_0 = 0;
#         for (i = 0; i < 399; i = i + 1) s_0 = s_0 + raw[i];
#         scores_flat[0*32 +: 32] = s_0;
#         s_1 = 0;
#         for (i = 399; i < 798; i = i + 1) s_1 = s_1 + raw[i];
#         scores_flat[1*32 +: 32] = s_1;
#         s_2 = 0;
#         for (i = 798; i < 1198; i = i + 1) s_2 = s_2 + raw[i];
#         scores_flat[2*32 +: 32] = s_2;
#         s_3 = 0;
#         for (i = 1198; i < 1598; i = i + 1) s_3 = s_3 + raw[i];
#         scores_flat[3*32 +: 32] = s_3;
#         s_4 = 0;
#         for (i = 1598; i < 1997; i = i + 1) s_4 = s_4 + raw[i];
#         scores_flat[4*32 +: 32] = s_4;
#         s_5 = 0;
#         for (i = 1997; i < 2397; i = i + 1) s_5 = s_5 + raw[i];
#         scores_flat[5*32 +: 32] = s_5;
#         s_6 = 0;
#         for (i = 2397; i < 2797; i = i + 1) s_6 = s_6 + raw[i];
#         scores_flat[6*32 +: 32] = s_6;
#         s_7 = 0;
#         for (i = 2797; i < 3197; i = i + 1) s_7 = s_7 + raw[i];
#         scores_flat[7*32 +: 32] = s_7;
#         s_8 = 0;
#         for (i = 3197; i < 3597; i = i + 1) s_8 = s_8 + raw[i];
#         scores_flat[8*32 +: 32] = s_8;
#         s_9 = 0;
#         for (i = 3597; i < 3996; i = i + 1) s_9 = s_9 + raw[i];
#         scores_flat[9*32 +: 32] = s_9;
#     end
#
# endmodule
